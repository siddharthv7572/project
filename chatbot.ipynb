# %%
from openai import OpenAI

client = OpenAI()  # key automatically loaded
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from openai import OpenAI
#       3 client = OpenAI()  # key automatically loaded
#
# ModuleNotFoundError: No module named 'openai'

# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": "Hello"}]
)

print(response.choices[0].message.content)

# %%
from flask import Flask, request, jsonify
from openai import OpenAI

app = Flask(__name__)

# API key will be loaded automatically
client = OpenAI()

@app.route("/")
def home():
    return "Chatbot is running!"

@app.route("/chat", methods=["POST"])
def chat():
    user_message = request.json["message"]

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": user_message}
        ]
    )

    bot_reply = response.choices[0].message.content
    return jsonify({"reply": bot_reply})

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 from flask import Flask, request, jsonify
# ----> 2 from openai import OpenAI
#       4 app = Flask(__name__)
#       6 # API key will be loaded automatically
#
# ModuleNotFoundError: No module named 'openai'

# %%
python app.py
# Out:
#   Cell In[7], line 1
#     python app.py
#            ^
# SyntaxError: invalid syntax

# %%
from flask import Flask, request, jsonify
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from flask import Flask, request, jsonify
# ----> 2 from openai import OpenAI
#
# ModuleNotFoundError: No module named 'openai'

# %%
from flask import Flask, request, jsonify
from openai import OpenAI

app = Flask(__name__)
client = OpenAI()   # API key auto loaded

@app.route("/")
def home():
    return "ML Chatbot API is running"

@app.route("/chat", methods=["POST"])
def chat():
    user_message = request.json["message"]

    response = client.responses.create(
        model="gpt-4.1-mini",
        input=user_message
    )

    bot_reply = response.output_text

    return jsonify({
        "user": user_message,
        "bot": bot_reply
    })

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from flask import Flask, request, jsonify
# ----> 2 from openai import OpenAI
#       4 app = Flask(__name__)
#       5 client = OpenAI()   # API key auto loaded
#
# ModuleNotFoundError: No module named 'openai'

# %%
from openai import OpenAI

client = OpenAI()  # key automatically loaded
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[1], line 1
#
# ----> 1 from openai import OpenAI
#
#       3 client = OpenAI()  # key automatically loaded
#
#
#
# ModuleNotFoundError: No module named 'openai'
